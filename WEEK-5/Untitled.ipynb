# %%
accounting= {"Adewumi":"Ayomide","Agbakuru-Nwogu":"Chukwunonye","Akinde":"Oluwatimilehin","Ebi":"Staphinie","Icha":"Ayonete","Ikpati":"Eche","Obasogie":"Daisy","Obi":"Samuel","Obialor":"Betha","Olowokere":"Akorede","Olubuade":"Rasheed","Osemeke":"Daniel"}
for i in accounting:
    print(i,accounting[i])
    
    
administration={"Egboro":"Jason","Eleri":"Otu","Eze":"Onyinyechi","Okoch-Ojeah":"Raphael","Okolo":"Victor","Umeh":"Ejike"}
for i in administration:
    print(i,administration[i])
    
delivery= {"Adoh-Ajagbe":"Oshim","Atelly":"Daniel","Azogu":"Onywekachi","Beture":"Shalom","Ejedimu":"Edward","Iloenyosi":"Micheal","Iyawe":"Oluwadamilola","Ogbonna":"Boluwatife","Oigbochie":"Mary","Quadri":"Oluwafukunmi","Ube-Ibe":"Uchenna"}
for i in delivery:
    print(i,delivery[i])
    
logistics={"Adeniran":"Oluwatamilore","Agbakwuru":"Chiemeziem","Arinka":"Osose","Chukwuma":"Nedi","Ezeonye":"Makuochukwu","Giwa":"Moyosore","Nwokolo":"Chijindu","Nwotokubo":"Joseph","Okoro":"Derek","Ossai":"Mary-Cynthia","Peter":"Owoede"}
for i in logistics:
    print(i,logistics[i])
    
    
    
    
def accounting(name2):
    window=tk.Toplevel(root)
    window.title("Accounting department box")
    window.geometry("900x600")
    
    label_1=tk.Label(window,text=f"Welcome {name2}\n")
    label_1.pack()
    label_2=tk.Label(window,text="This is Accounting department")
    label_2.pack()
    label_3=tk.Label(window,text="Department members")
    label_3.pack()
    accounting= {"Adewumi":"Ayomide","Agbakuru-Nwogu":"Chukwunonye","Akinde":"Oluwatimilehin","Ebi":"Staphinie","Icha":"Ayonete","Ikpati":"Eche","Obasogie":"Daisy","Obi":"Samuel","Obialor":"Betha","Olowokere":"Akorede","Olubuade":"Rasheed","Osemeke":"Daniel"}
    for i in accounting:
        label_4=tk.Label(window,text= accounting[i])
        label_4.pack()
    
    root.mainloop()
    
def administration(name2):
    window=tk.Toplevel(root)
    window.title("Administration department box")
    window.geometry("900x600")
    
    label_1=tk.Label(window,text=f"Welcome {name2}\n")
    label_1.pack()
    label_2=tk.Label(window,text="This is Administration department")
    label_2.pack()
    label_3=tk.Label(window,text="Department members")
    label_3.pack()
    administration={"Egboro":"Jason","Eleri":"Otu","Eze":"Onyinyechi","Okoch-Ojeah":"Raphael","Okolo":"Victor","Umeh":"Ejike"}
    for i in administration:
         label_4=tk.Label(window,text=administration[i])
         label_4.pack()
    
    root.mainloop()
    
def delivery(name2):
    window=tk.Toplevel(root)
    window.title("Delivery department box")
    window.geometry("900x600")
    
    label_1=tk.Label(window,text=f"Welcome {name2}\n")
    label_1.pack()
    label_2=tk.Label(window,text="This is Delivery department")
    label_2.pack()
    label_3=tk.Label(window,text="Department members")
    label_3.pack()
    delivery= {"Adoh-Ajagbe":"Oshim","Atelly":"Daniel","Azogu":"Onywekachi","Beture":"Shalom","Ejedimu":"Edward","Iloenyosi":"Micheal","Iyawe":"Oluwadamilola","Ogbonna":"Boluwatife","Oigbochie":"Mary","Quadri":"Oluwafukunmi","Ube-Ibe":"Uchenna"}
    for i in delivery:
         label_4=tk.Label(window,text=delivery[i])
         label_4.pack()
    
    root.mainloop()
    
def logistics(name2):
    window=tk.Toplevel(root)
    window.title("Logistics department box")
    window.geometry("900x600")
    
    label_1=tk.Label(window,text=f"Welcome {name2}\n")
    label_1.pack()
    label_2=tk.Label(window,text="This is Logistics department")
    label_2.pack()
    label_3=tk.Label(window,text="Department members")
    label_3.pack()
    logistics={"Adeniran":"Oluwatamilore","Agbakwuru":"Chiemeziem","Arinka":"Osose","Chukwuma":"Nedi","Ezeonye":"Makuochukwu","Giwa":"Moyosore","Nwokolo":"Chijindu","Nwotokubo":"Joseph","Okoro":"Derek","Ossai":"Mary-Cynthia","Peter":"Owoede"}
    for i in logistics:
         label_4=tk.Label(window,text=logistics[i])
         label_4.pack()
    
    
    root.mainloop()
    
    
     if name1 == "Mary" and name2== "Mary"  and department == "cos102":
            accounting(name2)
            
    elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
        administration(name2)
        
    elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
        delivery(name2)
        
    elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
        logistics(name2)
    
    else:
        messagebox.showerror("Login","invalid name or department")
# Out:
# Adewumi Ayomide
# Agbakuru-Nwogu Chukwunonye
# Akinde Oluwatimilehin
# Ebi Staphinie
# Icha Ayonete
# Ikpati Eche
# Obasogie Daisy
# Obi Samuel
# Obialor Betha
# Olowokere Akorede
# Olubuade Rasheed
# Osemeke Daniel
# Egboro Jason
# Eleri Otu
# Eze Onyinyechi
# Okoch-Ojeah Raphael
# Okolo Victor
# Umeh Ejike
# Adoh-Ajagbe Oshim
# Atelly Daniel
# Azogu Onywekachi
# Beture Shalom
# Ejedimu Edward
# Iloenyosi Micheal
# Iyawe Oluwadamilola
# Ogbonna Boluwatife
# Oigbochie Mary
# Quadri Oluwafukunmi
# Ube-Ibe Uchenna
# Adeniran Oluwatamilore
# Agbakwuru Chiemeziem
# Arinka Osose
# Chukwuma Nedi
# Ezeonye Makuochukwu
# Giwa Moyosore
# Nwokolo Chijindu
# Nwotokubo Joseph
# Okoro Derek
# Ossai Mary-Cynthia
# Peter Owoede

# %%
elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
        administration(name2)
        
    elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
        delivery(name2)
        
    elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
        logistics(name2)
# Out:
#   File "<tokenize>", line 4
#     elif name1 == "Mary" and name2 == "Mary" and department == "cos102":
#     ^
# IndentationError: unindent does not match any outer indentation level
