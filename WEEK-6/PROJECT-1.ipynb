# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image

def ibejuequal(name):
    window=tk.Toplevel(root)
    window.title("Door step logistics")
    window.geometry("300x200")
    
    label_1=tk.Label(window,text=f"Thank you {name} for choosing Door step logistics\n")
    label_1.pack()
    label_2=tk.Label(window,text="Your bill is N5,000")
    label_2.pack()
    
    root.mainloop()
    
def ibejuless(name):
    window=tk.Toplevel(root)
    window.title("Door step logistics")
    window.geometry("300x200")
    
    label_1=tk.Label(window,text=f"Thank you {name} for choosing Door step logistics\n")
    label_1.pack()
    label_2=tk.Label(window,text="Your bill is N3,500")
    label_2.pack()
    
    root.mainloop()
    
def epeequal(name):
    window=tk.Toplevel(root)
    window.title("Door step logistics")
    window.geometry("300x200")
    
    label_1=tk.Label(window,text=f"Thank you {name} for choosing Door step logistics\n")
    label_1.pack()
    label_2=tk.Label(window,text="Your bill is N10,000")
    label_2.pack()
    
    root.mainloop()
    
def epeless(name):
    window=tk.Toplevel(root)
    window.title("Door step logistics")
    window.geometry("300x200")
    
    label_1=tk.Label(window,text=f"Thank you {name} for choosing Door step logistics\n")
    label_1.pack()
    label_2=tk.Label(window,text="Your bill is N5,000")
    label_2.pack()
    
    root.mainloop()
    
def submit():
    name= name_entry.get()
    location = int(location_entry.get())
    weight = int(weight_entry.get())
    
    
    if location == 1 and weight == 10:
        ibejuequal(name)
    elif location == 1 and weight < 10:
        ibejuless(name)
    elif location == 2 and weight == 10:
        epeequal(name)
    elif location == 2 and weight < 10:
        epeless(name)
    else:
        messagebox.showerror("Door step ","invalid username or password")
root = tk.Tk()
root.title("Door step logistics")
root.geometry("700x400")

name_label = tk.Label(root,text="Name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

location_label = tk.Label(root,text="Location\n""Enter 1 for Ibeju lekki\n"" Enter 2 for Epe")
location_label.pack()
location_entry = tk.Entry(root)
location_entry.pack()

weight_label = tk.Label(root,text="Weight")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

submit_button = tk.Button(root,text="Submit",command=submit)
submit_button.pack()

root.mainloop()
